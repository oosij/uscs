# %%
## import load !
import pandas as pd
import schedule
import openpyxl
import re
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
#from webdriver_manager.chrome import ChromeDriverManager

import datetime
from datetime import datetime as dtime
from dateutil.parser import parse
from time import strptime
import pytz

import nltk
from nltk.corpus import stopwords
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk import sent_tokenize

import time
import pymysql

# %%
# 로컬 DB TEST 접속
db = pymysql.connect(host='127.0.0.1',  port = 3306 , user = 'root',
                           password = "1234", db = 'jisoo', charset = 'utf8')


headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
        'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}

# %%
# 시간 재기용
start = time.time()

#select_ticker = ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'NVDA', 'PEP', 'COST', 'ASML', 'AVGO']
select_ticker = 0  ## 선택없이 전체
ticker_list = stock_info_load(db, select_ticker) # 0 이면 전체 할수있도록
nofind_symbol_list = notfind_symbol_load()

select_stock = []

cnt = 0
for n in range(len(ticker_list)):
    symbol = ticker_list[n][0]
    if symbol in nofind_symbol_list:
        cnt += 1
        continue
    select_stock.append(ticker_list[n])

print( len(nofind_symbol_list) , '/',len(ticker_list) , '=', len(select_stock))
# Out:
# 6484 / 11352 = 4868

# %%
usa_est = datetime.datetime.now(pytz.timezone('America/New_York'))

month = date_zero_padding(usa_est.month)
days = date_zero_padding(usa_est.day)
ymd_date = str(usa_est.year) + '-' + str(month) + '-' + str(days)

## 복구 용 

ymd_date_list = ['2022-11-08', '2022-11-09','2022-11-10', '2022-11-11', '2022-11-12',  '2022-11-13',  '2022-11-14']
category = 'stock_news'

# %%
for i in range(len(ymd_date_list)):
    ymd_date = ymd_date_list[i]
    print(ymd_date)
    result = finviz_news_crawler(db, category, select_stock, ymd_date)
print('done!')
# Out:
# 2022-11-08
# MSFT is runing...
# Abnormal detected : https://finance.yahoo.com/news/microsoft-cloud-sparks-complaint-eu-230100051.html
# AMZN is runing...
# Abnormal detected : https://finance.yahoo.com/news/microsoft-cloud-sparks-complaint-eu-230100051.html
# GOOG is runing...
# GOOGL is runing...
# AAPL is runing...
# Abnormal detected : https://finance.yahoo.com/news/shares-chinas-goertek-tumble-foreign-024532871.html
# BABA is runing...
# JNJ is runing...
# JPM is runing...
# XOM is runing...
# V is day noting
# WMT is runing...
# BAC is runing...
# PFE is runing...
# VZ is runing...
# UNH is runing...
# PG is runing...
# WFC is runing...
# date miss
# date miss
# INTC is day noting
# CVX is runing...
# KO is runing...
# MRK is runing...
# HD is runing...
# MA is day noting
# CSCO is runing...
# TM is runing...
# BA is runing...
# TSM is runing...
# ORCL is day noting
# date miss
# DIS is runing...
# CMCSA is runing...
# PEP is day noting
# date miss
# MCD is runing...
# C_pk is runing...
# C is runing...
# Abnormal detected : https://finance.yahoo.com/news/2-citigroup-buy-deutsche-bank-003736795.html
# Abnormal detected : https://finance.yahoo.com/news/1-citigroup-buy-deutsche-bank-003736886.html
# Abnormal detected : https://finance.yahoo.com/news/citigroup-purchase-deutsche-bank-license-000715794.html
# Abnormal detected : https://finance.yahoo.com/news/citigroup-buy-deutsche-bank-license-000715159.html
# ABBV is runing...
# BP is runing...
# NFLX is runing...
# AMGN is runing...
# LLY is runing...
# SAP is runing...
# ABT is runing...
# NKE is runing...
# MDT is runing...
# BUD is runing...
# BHP is runing...
# MMM is runing...
# ADBE is runing...
# PM is runing...
# date miss
# IBM is runing...
# CRM is runing...
# date miss
# PYPL is runing...
# UNP is runing...
# date miss
# AZN is runing...
# GSK is day noting
# AVGO is runing...
# MO is day noting
# ACN is runing...
# TD is day noting
# date miss
# NVO is day noting
# COST is day noting
# date miss
# TMO is runing...
# TXN is day noting
# FOX is runing...
# FOXA is runing...
# GILD is runing...
# CVS is runing...
# LIN is runing...
# DEO is runing...
# UPS is runing...
# AXP is runing...
# NVDA is runing...
# NEE is runing...
# date miss
# RIO is runing...
# BKNG is runing...
# SBUX is runing...
# SAN is runing...
# BMY is runing...
# USB is runing...
# CAT is runing...
# date miss
# date miss
# BTI is runing...
# VALE is runing...
# EQNR is runing...
# COP is runing...
# CI is runing...
# GE is runing...
# MS is runing...
# DHR is runing...
# ABEV is runing...
# AMT is runing...
# date miss
# date miss
# QCOM is runing...
# BBD is runing...
# ENB is day noting
# CME is runing...
# ASML is day noting
# WBA is runing...
# GS is runing...
# BIIB is runing...
# date miss
# BLK is runing...
# DUK is runing...
# E is runing...
# MDLZ is runing...
# CB is runing...
# date miss
# date miss
# EPD is runing...
# ADP is runing...
# date miss
# TMUS is runing...
# VMW is runing...
# BIDU is runing...
# date miss
# PNC is runing...
# CNI is runing...
# date miss
# date miss
# KHC is runing...
# SLB is runing...
# ISRG is day noting
# date miss
# VOD is day noting
# date miss
# CL is runing...
# date miss
# UBS is runing...
# Abnormal detected : https://finance.yahoo.com/news/german-officials-search-bank-russian-104108970.html
# date miss
# HMC is runing...
# DE is runing...
# BSBR is runing...
# OXY is runing...
# date miss
# D is runing...
# date miss
# date miss
# SMFG is runing...
# EL is runing...
# GM is runing...
# date miss
# date miss
# date miss
# PUK is runing...
# date miss
# date miss
# ILMN is day noting
# VRTX is runing...
# ING is day noting
# ORAN is day noting
# date miss
# SPGI is runing...
# EXC is runing...
# date miss
# BMO is runing...
# NOC is runing...
# FDX is runing...
# MPC is day noting
# HCA is runing...
# ECL is runing...
# REGN is runing...
# date miss
# PSX is runing...
# date miss
# date miss
# NSC is day noting
# date miss
# date miss
# ZTS is runing...
# MMC is runing...
# date miss
# BAM is runing...
# Abnormal detected : https://finance.yahoo.com/news/american-equity-plunges-clash-brookfield-204807209.html
# KMB is runing...
# WM is runing...
# HUM is runing...
# COF is runing...
# date miss
# ET is runing...
# CTSH is runing...
# date miss
# MAR is runing...
# MU is day noting
# SHW is runing...
# date miss
# BX is runing...
# date miss
# date miss
# EC is runing...
# ATVI is runing...
# Abnormal detected : https://finance.yahoo.com/news/eu-antitrust-regulators-probe-microsofts-163155761.html
# Abnormal detected : https://finance.yahoo.com/news/microsoft-activision-deal-faces-depth-163000891.html
# date miss
# KMI is day noting
# date miss
# date miss
# date miss
# APD is runing...
# BAX is day noting
# date miss
# PRU is runing...
# date miss
# date miss
# TGT is day noting
# CCL is runing...
# CUK is runing...
# date miss
# AFL is runing...
# date miss
# date miss
# date miss
# BCS is runing...
# FIS is runing...
# date miss
# DELL is runing...
# DAL is runing...
# NOK is day noting
# VLO is runing...
# AMAT is day noting
# HPQ is runing...
# date miss
# NOW is runing...
# F is runing...
# JD is runing...
# date miss
# ROST is runing...
# STZ is runing...
# date miss
# CNQ is runing...
# date miss
# ADI is runing...
# SRE is runing...
# date miss
# date miss
# ETN is runing...
# MFC is runing...
# date miss
# NTR is runing...
# CS is runing...
# JCI is runing...
# DG is runing...
# YUM is runing...
# date miss
# ALL is day noting
# ERIC is day noting
# EQIX is runing...
# date miss
# CP is runing...
# AMTD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# ORLY is runing...
# date miss
# date miss
# date miss
# LUV is runing...
# NXPI is runing...
# date miss
# MPLX is runing...
# WELL is runing...
# EA is day noting
# date miss
# date miss
# date miss
# S is runing...
# PDD is runing...
# XEL is day noting
# HAL is runing...
# EQR is day noting
# date miss
# SCCO is day noting
# date miss
# date miss
# date miss
# ED is runing...
# date miss
# GIS is runing...
# PXD is runing...
# date miss
# RSG is runing...
# CNC is runing...
# ADM is runing...
# date miss
# date miss
# date miss
# date miss
# IR is runing...
# [1] TWTR
# date miss
# date miss
# UAL is runing...
# FTV is runing...
# CRH is runing...
# MCK is runing...
# HRL is runing...
# HSY is runing...
# TROW is runing...
# DLTR is runing...
# KR is runing...
# date miss
# DLR is runing...
# date miss
# date miss
# date miss
# date miss
# ZBH is runing...
# SPOT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# A is runing...
# WIT is runing...
# date miss
# date miss
# HLT is runing...
# FMS is runing...
# TEAM is day noting
# RCL is runing...
# date miss
# date miss
# IMO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# TSN is runing...
# date miss
# TU is runing...
# DTE is runing...
# date miss
# date miss
# date miss
# CLX is runing...
# date miss
# HPE is runing...
# date miss
# EIX is runing...
# date miss
# AMD is runing...
# SSL is runing...
# date miss
# date miss
# SWK is runing...
# date miss
# SBAC is runing...
# O is runing...
# date miss
# date miss
# NEM is runing...
# date miss
# date miss
# date miss
# date miss
# CQP is runing...
# date miss
# MKC is day noting
# TDG is runing...
# date miss
# DB is runing...
# Abnormal detected : https://finance.yahoo.com/news/citigroup-purchase-deutsche-bank-license-000715794.html
# Abnormal detected : https://finance.yahoo.com/news/citigroup-buy-deutsche-bank-license-000715159.html
# PANW is runing...
# date miss
# BXP is runing...
# IP is runing...
# LULU is runing...
# date miss
# date miss
# date miss
# EXPE is runing...
# CHKP is day noting
# date miss
# date miss
# KKR is runing...
# Abnormal detected : https://finance.yahoo.com/news/sec-whatsapp-probe-reaches-pe-001430956.html
# date miss
# date miss
# OMC is runing...
# date miss
# MCHP is runing...
# GPN is runing...
# FITB is runing...
# AWK is runing...
# IDXX is runing...
# KEY is day noting
# date miss
# date miss
# CHD is runing...
# date miss
# LNG is runing...
# SNN is runing...
# HIG is runing...
# date miss
# AEE is runing...
# ESS is runing...
# ABC is runing...
# GWW is runing...
# date miss
# FCX is runing...
# BMRN is day noting
# date miss
# AMP is runing...
# date miss
# ETR is runing...
# IAC is runing...
# ANET is runing...
# MGA is runing...
# date miss
# date miss
# date miss
# TAL is runing...
# NTAP is runing...
# ALGN is runing...
# date miss
# date miss
# SHOP is day noting
# date miss
# AAL is runing...
# EVRG is runing...
# date miss
# IFF is runing...
# date miss
# BSAC is runing...
# L is runing...
# date miss
# MELI is day noting
# FRC is runing...
# BBY is runing...
# FTS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DHI is runing...
# date miss
# WPP is runing...
# RYAAY is runing...
# date miss
# date miss
# date miss
# MGM is runing...
# date miss
# MMP is runing...
# date miss
# NDAQ is day noting
# VMC is runing...
# CAH is runing...
# date miss
# LEN is runing...
# date miss
# date miss
# date miss
# VEEV is runing...
# MTD is runing...
# NLY is runing...
# date miss
# date miss
# date miss
# date miss
# TAP is runing...
# PFG is runing...
# date miss
# MRO is day noting
# CNHI is runing...
# PCG is runing...
# CMG is runing...
# GRMN is runing...
# date miss
# HST is runing...
# DRI is runing...
# date miss
# CINF is runing...
# date miss
# CE is runing...
# date miss
# date miss
# CNA is runing...
# date miss
# TECK is runing...
# date miss
# date miss
# MTCH is runing...
# ROL is runing...
# date miss
# MOS is runing...
# WYNN is runing...
# date miss
# VNO is day noting
# date miss
# ELAN is runing...
# date miss
# KEYS is runing...
# date miss
# TTWO is runing...
# date miss
# CMA is runing...
# date miss
# EXPD is runing...
# DVN is day noting
# IT is runing...
# LNC is runing...
# FTNT is runing...
# TXT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SWKS is runing...
# DGX is day noting
# date miss
# LW is runing...
# date miss
# CBOE is runing...
# BURL is day noting
# date miss
# UHS is runing...
# KSS is runing...
# Abnormal detected : https://finance.yahoo.com/news/levis-names-kohls-michelle-gass-135759161.html
# date miss
# STX is runing...
# SJM is runing...
# GDDY is day noting
# date miss
# WDC is runing...
# APA is runing...
# ZNH is runing...
# Abnormal detected : https://finance.yahoo.com/news/1-chinas-biggest-air-show-090353146.html
# ATO is runing...
# date miss
# MRVL is runing...
# date miss
# RJF is runing...
# date miss
# date miss
# date miss
# date miss
# UDR is runing...
# CAG is runing...
# date miss
# date miss
# TRU is runing...
# INVH is runing...
# date miss
# DXCM is day noting
# date miss
# IHG is runing...
# date miss
# date miss
# date miss
# SQM is runing...
# date miss
# date miss
# FANG is runing...
# Abnormal detected : https://finance.yahoo.com/news/diamondback-energy-sees-u-shale-144339204.html
# date miss
# date miss
# ODFL is runing...
# date miss
# TPR is runing...
# IEX is runing...
# CPB is runing...
# LNT is runing...
# date miss
# date miss
# date miss
# FFIV is runing...
# GPS is runing...
# REG is runing...
# date miss
# AKAM is runing...
# date miss
# date miss
# date miss
# JKHY is runing...
# NCLH is runing...
# Abnormal detected : https://finance.yahoo.com/news/norwegian-cruise-results-sail-past-124203365.html
# Abnormal detected : https://finance.yahoo.com/news/norwegian-cruise-results-sail-past-124203980.html
# date miss
# AEM is runing...
# Abnormal detected : https://finance.yahoo.com/news/5-yamana-gold-backs-agnico-131340067.html
# Abnormal detected : https://finance.yahoo.com/news/4-yamana-gold-backs-agnico-131340785.html
# Abnormal detected : https://finance.yahoo.com/news/3-agnico-eagle-pan-american-131340544.html
# Abnormal detected : https://finance.yahoo.com/news/2-agnico-eagle-pan-american-131340323.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-backs-agnico-eagle-122827046.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-agrees-agnico-pan-122827880.html
# Abnormal detected : https://finance.yahoo.com/news/agnico-eagle-pan-american-buy-122827789.html
# IRM is runing...
# date miss
# NI is runing...
# date miss
# CVE is runing...
# date miss
# date miss
# MAS is runing...
# AGNC is runing...
# CEA is runing...
# date miss
# JNPR is runing...
# [2] Y
# HLF is runing...
# date miss
# date miss
# date miss
# M is runing...
# date miss
# date miss
# EDU is runing...
# DVA is runing...
# date miss
# RGA is runing...
# date miss
# date miss
# FNF is runing...
# TWLO is day noting
# date miss
# date miss
# CGC is day noting
# date miss
# date miss
# BSMX is runing...
# date miss
# date miss
# NVR is runing...
# FRT is runing...
# XRAY is runing...
# OTEX is runing...
# DBX is runing...
# date miss
# date miss
# date miss
# ELS is runing...
# PKI is runing...
# date miss
# date miss
# HII is runing...
# date miss
# date miss
# DOX is runing...
# PKG is runing...
# date miss
# date miss
# ALB is runing...
# AFG is runing...
# EXAS is runing...
# date miss
# TRMB is runing...
# QGEN is runing...
# LDOS is runing...
# IPG is runing...
# date miss
# ANGI is day noting
# date miss
# date miss
# JWN is runing...
# date miss
# OGE is runing...
# date miss
# date miss
# date miss
# JAZZ is runing...
# BG is runing...
# date miss
# date miss
# SNAP is runing...
# date miss
# SPR is runing...
# date miss
# BRO is day noting
# date miss
# date miss
# date miss
# FDS is runing...
# date miss
# date miss
# date miss
# date miss
# ALLE is runing...
# date miss
# IONS is runing...
# TDY is runing...
# TRIP is runing...
# date miss
# date miss
# date miss
# H is runing...
# BWA is runing...
# MFGP is runing...
# date miss
# ST is runing...
# date miss
# date miss
# XPO is runing...
# ARMK is runing...
# date miss
# date miss
# date miss
# SEIC is runing...
# USFD is runing...
# date miss
# IVZ is day noting
# PAYC is runing...
# date miss
# date miss
# OHI is runing...
# date miss
# TYL is runing...
# OKTA is runing...
# date miss
# ON is runing...
# date miss
# NWSA is runing...
# date miss
# date miss
# NWS is runing...
# date miss
# UNM is runing...
# WES is runing...
# date miss
# date miss
# date miss
# BIO is runing...
# date miss
# SLG is day noting
# NBIX is runing...
# NDSN is runing...
# DOCU is day noting
# date miss
# ARCC is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PNR is runing...
# ACB is runing...
# RNG is runing...
# UHAL is runing...
# NIO is day noting
# TLRY is day noting
# date miss
# date miss
# date miss
# date miss
# GWRE is runing...
# date miss
# VOYA is runing...
# EPAM is runing...
# date miss
# date miss
# KAR is runing...
# KRC is day noting
# BERY is runing...
# KIM is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# POST is runing...
# date miss
# ALV is runing...
# date miss
# WEX is runing...
# EHC is runing...
# TIGO is runing...
# ARW is runing...
# CSL is runing...
# date miss
# WWE is runing...
# POOL is day noting
# ETSY is day noting
# date miss
# CBD is runing...
# date miss
# date miss
# date miss
# NATI is runing...
# date miss
# SABR is runing...
# CFR is runing...
# date miss
# JEF is runing...
# CPRI is runing...
# date miss
# date miss
# CCK is runing...
# date miss
# JLL is runing...
# Abnormal detected : https://finance.yahoo.com/news/acre-closes-424m-freddie-mac-180000156.html
# date miss
# PRGO is runing...
# ALSN is runing...
# COLM is runing...
# date miss
# date miss
# date miss
# YPF is runing...
# date miss
# HOG is runing...
# date miss
# MASI is runing...
# date miss
# AIZ is runing...
# TER is runing...
# date miss
# date miss
# date miss
# STNE is runing...
# DCI is runing...
# CG is runing...
# Abnormal detected : https://finance.yahoo.com/news/sec-whatsapp-probe-reaches-pe-001430956.html
# STWD is runing...
# MRNA is day noting
# HUBB is runing...
# FICO is runing...
# TECH is runing...
# CIEN is runing...
# COTY is runing...
# date miss
# PLNT is runing...
# GNTX is runing...
# LPLA is runing...
# date miss
# HP is runing...
# date miss
# date miss
# CC is day noting
# AMG is runing...
# date miss
# date miss
# PK is runing...
# date miss
# date miss
# date miss
# GLPG is day noting
# CUBE is runing...
# HRB is runing...
# date miss
# date miss
# date miss
# date miss
# G is runing...
# RS is runing...
# ZS is runing...
# APO is runing...
# Abnormal detected : https://finance.yahoo.com/news/sec-whatsapp-probe-reaches-pe-001430956.html
# HAE is runing...
# TTD is runing...
# date miss
# date miss
# TOL is day noting
# date miss
# FAF is runing...
# date miss
# date miss
# HUN is runing...
# HXL is runing...
# date miss
# CAE is runing...
# date miss
# date miss
# date miss
# HUBS is runing...
# GT is runing...
# GOOS is runing...
# date miss
# date miss
# date miss
# SIX is runing...
# NYCB is runing...
# date miss
# PII is runing...
# date miss
# FSLR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CCU is runing...
# date miss
# date miss
# MDU is runing...
# LEG is runing...
# CDAY is runing...
# date miss
# date miss
# date miss
# date miss
# CASY is day noting
# date miss
# date miss
# date miss
# JHX is runing...
# date miss
# date miss
# ALKS is runing...
# date miss
# date miss
# KOF is runing...
# date miss
# WH is runing...
# date miss
# MORN is runing...
# NEWR is runing...
# date miss
# TPL is runing...
# CCJ is runing...
# LOPE is day noting
# PB is runing...
# SAGE is runing...
# FCNCA is runing...
# date miss
# PODD is runing...
# BRKR is runing...
# date miss
# TDC is runing...
# NFG is runing...
# ASH is day noting
# CTLT is runing...
# date miss
# date miss
# OSK is runing...
# date miss
# date miss
# date miss
# AXS is runing...
# date miss
# date miss
# date miss
# date miss
# CVNA is day noting
# date miss
# LIVN is runing...
# SWI is runing...
# CHE is runing...
# MDB is day noting
# date miss
# date miss
# date miss
# date miss
# BRX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# HHC is runing...
# TXRH is runing...
# date miss
# ITT is runing...
# date miss
# date miss
# date miss
# JBGS is runing...
# PRI is runing...
# LSI is runing...
# [3] SHLX
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PBF is runing...
# date miss
# CHH is runing...
# WSM is day noting
# date miss
# LSTR is day noting
# date miss
# MEOH is runing...
# NJR is runing...
# NVT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# GMED is runing...
# date miss
# BB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# BHF is runing...
# date miss
# SLM is runing...
# NSP is runing...
# SE is runing...
# date miss
# date miss
# date miss
# SAVE is runing...
# ALE is runing...
# date miss
# date miss
# BILI is day noting
# PSTG is runing...
# PEGA is runing...
# date miss
# date miss
# JBL is runing...
# WEN is day noting
# date miss
# date miss
# date miss
# date miss
# TREX is day noting
# PNFP is day noting
# SR is runing...
# RBA is runing...
# date miss
# date miss
# COUP is runing...
# UMPQ is runing...
# CVI is runing...
# date miss
# date miss
# date miss
# ROKU is day noting
# date miss
# date miss
# CARG is runing...
# NXST is runing...
# [4] AMED
# EVR is runing...
# date miss
# date miss
# date miss
# date miss
# X is runing...
# date miss
# BTU is runing...
# date miss
# date miss
# EQC is runing...
# date miss
# VSAT is runing...
# date miss
# date miss
# SMG is runing...
# date miss
# SIGI is runing...
# date miss
# DECK is runing...
# date miss
# date miss
# RDN is runing...
# RIG is runing...
# RHP is runing...
# date miss
# OMF is runing...
# VET is runing...
# NGVT is runing...
# CPA is runing...
# date miss
# date miss
# date miss
# date miss
# TDOC is runing...
# EME is runing...
# PFGC is runing...
# date miss
# date miss
# MOR is runing...
# date miss
# HZNP is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# CIM is runing...
# date miss
# date miss
# date miss
# GPK is runing...
# date miss
# date miss
# ASB is runing...
# date miss
# date miss
# FNB is runing...
# date miss
# date miss
# ARRY is runing...
# date miss
# date miss
# TWO is runing...
# date miss
# date miss
# date miss
# date miss
# CHDN is runing...
# date miss
# date miss
# DKS is runing...
# date miss
# AR is runing...
# DAR is runing...
# date miss
# date miss
# NHI is runing...
# FCFS is runing...
# date miss
# date miss
# date miss
# date miss
# GNRC is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# NVCR is day noting
# date miss
# date miss
# date miss
# BJ is runing...
# date miss
# date miss
# date miss
# TRN is runing...
# IGT is runing...
# CBU is runing...
# date miss
# date miss
# CWK is day noting
# WWW is runing...
# RBC is runing...
# BLKB is runing...
# SRC is runing...
# date miss
# date miss
# SFM is runing...
# ICPT is runing...
# SHO is runing...
# ACIW is runing...
# SF is day noting
# AAN is runing...
# date miss
# EBS is runing...
# NOMD is runing...
# EXP is runing...
# TWOU is runing...
# date miss
# PRLB is runing...
# date miss
# FSK is runing...
# MGY is runing...
# date miss
# TKR is runing...
# date miss
# HOMB is day noting
# date miss
# date miss
# date miss
# THS is runing...
# date miss
# ASGN is runing...
# LGND is runing...
# date miss
# GFI is runing...
# Abnormal detected : https://finance.yahoo.com/news/5-yamana-gold-backs-agnico-131340067.html
# Abnormal detected : https://finance.yahoo.com/news/4-yamana-gold-backs-agnico-131340785.html
# Abnormal detected : https://finance.yahoo.com/news/3-agnico-eagle-pan-american-131340544.html
# Abnormal detected : https://finance.yahoo.com/news/2-agnico-eagle-pan-american-131340323.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-backs-agnico-eagle-122827388.html
# date miss
# date miss
# DORM is runing...
# date miss
# GDS is day noting
# DOC is runing...
# date miss
# date miss
# date miss
# LILA is runing...
# LILAK is runing...
# date miss
# date miss
# SAM is runing...
# date miss
# ATI is runing...
# TTEK is runing...
# NCR is runing...
# ATGE is runing...
# date miss
# FULT is runing...
# date miss
# MMSI is runing...
# date miss
# date miss
# ENR is runing...
# MANH is runing...
# date miss
# date miss
# date miss
# AVA is runing...
# date miss
# date miss
# BGCP is runing...
# date miss
# date miss
# R is runing...
# date miss
# date miss
# date miss
# date miss
# SBGI is runing...
# date miss
# date miss
# AB is runing...
# date miss
# date miss
# KW is runing...
# date miss
# CVLT is runing...
# REXR is runing...
# date miss
# RAMP is runing...
# date miss
# date miss
# date miss
# BOX is runing...
# date miss
# ORA is day noting
# date miss
# LITE is runing...
# date miss
# date miss
# date miss
# AEL is runing...
# Abnormal detected : https://finance.yahoo.com/news/american-equity-plunges-clash-brookfield-204807209.html
# EXPO is runing...
# date miss
# AMN is runing...
# date miss
# date miss
# OUT is runing...
# date miss
# date miss
# date miss
# SSD is runing...
# date miss
# date miss
# date miss
# STN is runing...
# date miss
# date miss
# NAVI is runing...
# date miss
# CLF is runing...
# date miss
# ORTX is day noting
# REZI is runing...
# SPB is runing...
# NEP is runing...
# date miss
# FIVN is runing...
# date miss
# FCN is runing...
# date miss
# HLI is runing...
# BYD is runing...
# ITGR is runing...
# date miss
# WTW is runing...
# ACAD is runing...
# ESRT is runing...
# MUSA is runing...
# VMI is runing...
# ALRM is runing...
# date miss
# date miss
# VSH is runing...
# SMAR is runing...
# date miss
# date miss
# date miss
# ONB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CPG is runing...
# TGNA is runing...
# AWR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# BPMC is runing...
# PSEC is runing...
# ARGO is runing...
# date miss
# KBR is runing...
# SFNC is runing...
# date miss
# date miss
# date miss
# BECN is runing...
# ACHC is runing...
# date miss
# IRBT is runing...
# date miss
# SHEN is runing...
# AUY is runing...
# Abnormal detected : https://finance.yahoo.com/news/5-yamana-gold-backs-agnico-131340067.html
# Abnormal detected : https://finance.yahoo.com/news/4-yamana-gold-backs-agnico-131340785.html
# Abnormal detected : https://finance.yahoo.com/news/3-agnico-eagle-pan-american-131340544.html
# Abnormal detected : https://finance.yahoo.com/news/2-agnico-eagle-pan-american-131340323.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-backs-agnico-eagle-122827046.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-agrees-agnico-pan-122827880.html
# Abnormal detected : https://finance.yahoo.com/news/agnico-eagle-pan-american-buy-122827789.html
# date miss
# PAAS is runing...
# Abnormal detected : https://finance.yahoo.com/news/5-yamana-gold-backs-agnico-131340067.html
# Abnormal detected : https://finance.yahoo.com/news/4-yamana-gold-backs-agnico-131340785.html
# Abnormal detected : https://finance.yahoo.com/news/3-agnico-eagle-pan-american-131340544.html
# Abnormal detected : https://finance.yahoo.com/news/2-agnico-eagle-pan-american-131340323.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-backs-agnico-eagle-122827046.html
# Abnormal detected : https://finance.yahoo.com/news/yamana-gold-agrees-agnico-pan-122827880.html
# Abnormal detected : https://finance.yahoo.com/news/agnico-eagle-pan-american-buy-122827789.html
# date miss
# date miss
# date miss
# date miss
# FIBK is runing...
# date miss
# date miss
# date miss
# date miss
# SWN is runing...
# SUN is runing...
# RES is runing...
# date miss
# ENV is runing...
# WAFD is runing...
# FOXF is runing...
# date miss
# RGEN is day noting
# date miss
# BL is day noting
# VIAV is runing...
# date miss
# date miss
# date miss
# MRCY is runing...
# date miss
# PRA is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# NOVT is runing...
# date miss
# SITC is runing...
# date miss
# WERN is runing...
# [5] AVLR
# date miss
# EYE is runing...
# CIGI is runing...
# date miss
# HALO is runing...
# date miss
# CALM is runing...
# date miss
# CCOI is runing...
# date miss
# QTWO is runing...
# date miss
# SEAS is runing...
# date miss
# date miss
# date miss
# IBA is runing...
# GTLS is runing...
# date miss
# date miss
# date miss
# TMHC is runing...
# AIT is runing...
# WNS is runing...
# date miss
# date miss
# SBH is runing...
# date miss
# date miss
# TEX is runing...
# FOLD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ENSG is runing...
# date miss
# DSGX is runing...
# EPC is runing...
# HRTX is runing...
# EE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# CMC is runing...
# CCO is runing...
# date miss
# date miss
# date miss
# TNDM is runing...
# date miss
# date miss
# ENLC is runing...
# date miss
# MTDR is day noting
# OPK is runing...
# date miss
# date miss
# TRMK is runing...
# SKT is day noting
# TENB is runing...
# date miss
# date miss
# date miss
# date miss
# CENT is runing...
# CENTA is runing...
# GRPN is runing...
# date miss
# QDEL is runing...
# date miss
# XHR is runing...
# date miss
# CRUS is runing...
# date miss
# date miss
# date miss
# date miss
# CAKE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FBP is runing...
# AVNS is runing...
# LADR is runing...
# date miss
# date miss
# [6] WRE
# AAT is day noting
# date miss
# MEDP is runing...
# AAON is day noting
# SM is day noting
# date miss
# date miss
# date miss
# CROX is runing...
# date miss
# [7] THC
# date miss
# WING is runing...
# date miss
# date miss
# KBH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SIG is runing...
# ROG is runing...
# CAR is day noting
# date miss
# CLBK is runing...
# SUPN is runing...
# EXLS is runing...
# date miss
# BDC is runing...
# GOL is runing...
# date miss
# date miss
# date miss
# date miss
# HAIN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# IAG is day noting
# ALGT is runing...
# RETA is runing...
# date miss
# FOCS is runing...
# date miss
# date miss
# ANAB is runing...
# PLAY is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# BZUN is runing...
# date miss
# date miss
# date miss
# SHAK is runing...
# date miss
# FCPT is runing...
# date miss
# date miss
# POWI is runing...
# date miss
# AIMC is runing...
# BLD is runing...
# SEDG is runing...
# date miss
# date miss
# MDC is runing...
# date miss
# date miss
# date miss
# PFS is runing...
# AVYA is day noting
# NWN is runing...
# DDS is runing...
# date miss
# date miss
# date miss
# CPE is runing...
# date miss
# CNS is runing...
# date miss
# FIX is runing...
# date miss
# AEIS is runing...
# PFSI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NEXA is runing...
# EVBG is runing...
# date miss
# BHVN is runing...
# SANM is day noting
# date miss
# date miss
# PLXS is runing...
# date miss
# JELD is runing...
# FBC is runing...
# WK is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# FWRD is runing...
# date miss
# ARCH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MED is runing...
# ABCB is runing...
# VRRM is runing...
# date miss
# date miss
# date miss
# date miss
# PCRX is day noting
# date miss
# SMPL is runing...
# date miss
# date miss
# date miss
# GME is day noting
# SUM is runing...
# MTH is runing...
# date miss
# CTRE is runing...
# OEC is runing...
# date miss
# IOSP is runing...
# date miss
# VRNS is runing...
# MSTR is runing...
# Abnormal detected : https://finance.yahoo.com/news/bitcoin-crypto-linked-equities-bounce-170900077.html
# date miss
# SG is runing...
# date miss
# date miss
# AGI is runing...
# date miss
# date miss
# date miss
# SSRM is runing...
# PJT is runing...
# RPD is day noting
# date miss
# ODP is runing...
# TBPH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# VNDA is runing...
# NSIT is runing...
# MRTX is runing...
# date miss
# OPI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GIII is runing...
# date miss
# date miss
# date miss
# KTOS is runing...
# date miss
# ADNT is runing...
# ACA is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CADE is day noting
# date miss
# ALEX is runing...
# date miss
# AMC is runing...
# Abnormal detected : https://finance.yahoo.com/news/amc-entertainment-beats-quarterly-revenue-212450177.html
# GNL is runing...
# BLDR is day noting
# MATX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# WD is runing...
# date miss
# date miss
# date miss
# date miss
# ATRA is runing...
# date miss
# date miss
# date miss
# date miss
# RDFN is runing...
# SSP is runing...
# CPK is runing...
# OII is runing...
# KLIC is runing...
# ABG is runing...
# date miss
# GTN is runing...
# HA is runing...
# OSIS is runing...
# date miss
# date miss
# LOMA is runing...
# DAVA is runing...
# DNOW is runing...
# date miss
# date miss
# date miss
# ATRI is day noting
# PZZA is runing...
# date miss
# date miss
# ATSG is runing...
# date miss
# date miss
# UVE is runing...
# date miss
# date miss
# date miss
# HASI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ZLAB is day noting
# KRNY is runing...
# date miss
# date miss
# date miss
# BHLB is runing...
# HUBG is runing...
# FCF is runing...
# BCOR is day noting
# date miss
# date miss
# TAC is runing...
# date miss
# date miss
# date miss
# CNNE is runing...
# SYNA is runing...
# OXM is runing...
# date miss
# CAL is runing...
# date miss
# date miss
# SSTK is runing...
# TRHC is runing...
# date miss
# date miss
# date miss
# WSFS is runing...
# date miss
# CWH is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# TRS is runing...
# date miss
# date miss
# PBI is runing...
# date miss
# date miss
# date miss
# date miss
# LPSN is day noting
# date miss
# DRQ is runing...
# ICFI is runing...
# PRAA is runing...
# date miss
# KRG is runing...
# date miss
# date miss
# date miss
# ATRC is runing...
# MGRC is runing...
# CWST is runing...
# BV is runing...
# date miss
# date miss
# MRC is runing...
# DDD is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NEO is runing...
# TYG is day noting
# PMT is runing...
# date miss
# date miss
# SPXC is runing...
# ATNI is runing...
# date miss
# date miss
# BRKL is runing...
# date miss
# RUN is day noting
# SBSI is runing...
# date miss
# date miss
# date miss
# KREF is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HURN is runing...
# KN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PUMP is runing...
# AQUA is runing...
# CBZ is runing...
# date miss
# date miss
# date miss
# ARCE is runing...
# date miss
# date miss
# date miss
# date miss
# BFS is runing...
# CSGS is runing...
# PACB is runing...
# SMP is runing...
# date miss
# AMWD is runing...
# date miss
# date miss
# JRVR is runing...
# date miss
# date miss
# date miss
# AAWW is runing...
# date miss
# date miss
# date miss
# WIRE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GPI is runing...
# date miss
# date miss
# NOG is runing...
# date miss
# SLDB is runing...
# date miss
# TCBK is runing...
# ATRO is runing...
# date miss
# date miss
# date miss
# date miss
# AG is runing...
# GCI is runing...
# date miss
# QUOT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GLOP is runing...
# date miss
# VVI is runing...
# TALO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [8] WETF
# date miss
# date miss
# STC is runing...
# SSYS is runing...
# date miss
# date miss
# date miss
# ATKR is runing...
# date miss
# OIS is runing...
# NMFC is runing...
# PRTY is runing...
# NBHC is day noting
# date miss
# date miss
# date miss
# MGPI is runing...
# date miss
# FBNC is runing...
# date miss
# date miss
# LRN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# XPER is runing...
# date miss
# date miss
# date miss
# date miss
# GPRK is runing...
# date miss
# date miss
# AHH is runing...
# NYMT is runing...
# MSC is day noting
# date miss
# date miss
# BHE is runing...
# date miss
# date miss
# ARVN is runing...
# SBLK is runing...
# PLYA is day noting
# HBM is runing...
# VREX is runing...
# date miss
# date miss
# GOGL is runing...
# date miss
# date miss
# date miss
# RYTM is runing...
# date miss
# date miss
# date miss
# ABR is runing...
# date miss
# CEIX is runing...
# date miss
# date miss
# date miss
# date miss
# MTRN is runing...
# ALG is runing...
# date miss
# ARR is runing...
# SCOR is runing...
# date miss
# KAI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# RCM is runing...
# SCSC is runing...
# date miss
# date miss
# date miss
# date miss
# SXI is runing...
# date miss
# date miss
# NVTA is runing...
# date miss
# MSEX is runing...
# CDXS is day noting
# date miss
# date miss
# date miss
# date miss
# TRUP is runing...
# date miss
# date miss
# CGBD is day noting
# date miss
# SKY is runing...
# date miss
# OBNK is runing...
# CTS is runing...
# GRC is runing...
# CLDT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# IRT is runing...
# ATNX is day noting
# date miss
# date miss
# date miss
# date miss
# RAD is runing...
# date miss
# AXGN is runing...
# CNXN is runing...
# date miss
# date miss
# date miss
# KELYA is runing...
# AMBC is runing...
# NVAX is runing...
# Abnormal detected : https://finance.yahoo.com/news/1-novavax-cuts-full-revenue-213131628.html
# JOE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DCPH is runing...
# date miss
# KFRC is runing...
# MLAB is runing...
# AGS is runing...
# GPMT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# FLWS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# HEES is day noting
# APLS is runing...
# date miss
# TDW is runing...
# date miss
# HSTM is runing...
# date miss
# date miss
# date miss
# NTRA is runing...
# CNSL is day noting
# GSBD is runing...
# date miss
# date miss
# date miss
# SYBT is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# PATK is runing...
# LXRX is day noting
# ASTE is day noting
# FORR is runing...
# SMCI is runing...
# CHS is runing...
# date miss
# date miss
# RVNC is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# SPWR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PRFT is runing...
# CLLS is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# OSUR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CTMX is runing...
# date miss
# date miss
# RUTH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HSKA is runing...
# date miss
# date miss
# FARO is runing...
# date miss
# date miss
# date miss
# MAXR is runing...
# date miss
# date miss
# date miss
# PARR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# UBX is day noting
# WTI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SP is day noting
# date miss
# GMS is runing...
# date miss
# GPRO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ARLO is runing...
# date miss
# ACIU is day noting
# date miss
# date miss
# date miss
# date miss
# JBSS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# APTX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# BY is runing...
# date miss
# date miss
# date miss
# date miss
# FFIC is runing...
# date miss
# date miss
# date miss
# SAH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# OCSL is runing...
# COLL is runing...
# NTG is day noting
# date miss
# [9] PZN
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# FFWM is runing...
# date miss
# DVAX is runing...
# date miss
# date miss
# date miss
# date miss
# MPX is runing...
# date miss
# date miss
# AGX is runing...
# date miss
# date miss
# KPTI is runing...
# NTLA is runing...
# date miss
# OMER is runing...
# date miss
# PEBO is runing...
# date miss
# date miss
# date miss
# date miss
# ASMB is day noting
# date miss
# date miss
# HSII is runing...
# date miss
# date miss
# date miss
# date miss
# TGI is runing...
# date miss
# date miss
# ADAP is runing...
# date miss
# [10] CCXI
# date miss
# date miss
# UIS is day noting
# date miss
# date miss
# LOCO is day noting
# XELA is day noting
# CHRS is runing...
# VKTX is runing...
# date miss
# RYAM is runing...
# date miss
# date miss
# PDS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CMTL is runing...
# date miss
# AUPH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ACLS is runing...
# GPRE is day noting
# TPB is runing...
# GLP is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# MTW is runing...
# UNFI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# YI is runing...
# MOD is runing...
# date miss
# date miss
# date miss
# INSW is runing...
# CAPL is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CHCT is runing...
# date miss
# date miss
# FLIC is runing...
# SRRK is runing...
# date miss
# DHIL is runing...
# ENPH is runing...
# date miss
# date miss
# date miss
# date miss
# SGRY is runing...
# date miss
# date miss
# ADTN is runing...
# date miss
# date miss
# date miss
# JG is day noting
# date miss
# GOOD is runing...
# date miss
# date miss
# date miss
# date miss
# NCNA is day noting
# date miss
# date miss
# date miss
# HZO is runing...
# date miss
# FET is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CALX is runing...
# date miss
# date miss
# date miss
# NGD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# GBLI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# PGC is runing...
# date miss
# SENS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# HTBI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# NX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# BBDC is runing...
# ANIK is runing...
# EVLO is day noting
# date miss
# date miss
# AVD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FRPH is day noting
# date miss
# date miss
# date miss
# PETS is runing...
# date miss
# date miss
# date miss
# HCKT is runing...
# date miss
# ZYME is runing...
# APEI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HCI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CURO is runing...
# OSTK is runing...
# date miss
# TISI is day noting
# date miss
# GLYC is runing...
# date miss
# date miss
# PEI is runing...
# date miss
# IIPR is runing...
# date miss
# date miss
# date miss
# UMH is runing...
# date miss
# ELF is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# GLDD is runing...
# date miss
# AHT is day noting
# date miss
# INO is runing...
# date miss
# date miss
# date miss
# date miss
# IMXI is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# BBSI is day noting
# JKS is day noting
# date miss
# EXPI is day noting
# date miss
# VRTV is runing...
# date miss
# date miss
# NVOS is runing...
# MG is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MODN is runing...
# date miss
# date miss
# EVI is runing...
# SBT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CRBP is runing...
# AVRO is runing...
# date miss
# date miss
# date miss
# date miss
# HRTG is runing...
# date miss
# CYTK is runing...
# date miss
# date miss
# [11] SRLP
# QTRX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ICHR is runing...
# date miss
# CLNE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# WLDN is runing...
# date miss
# date miss
# date miss
# TGTX is day noting
# MIXT is runing...
# date miss
# date miss
# date miss
# date miss
# EVRI is runing...
# date miss
# SVM is runing...
# date miss
# date miss
# date miss
# RRGB is runing...
# date miss
# date miss
# date miss
# BHB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# VECO is day noting
# date miss
# CCNE is day noting
# EOLS is runing...
# FRBK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# OXLC is day noting
# date miss
# DSX is runing...
# date miss
# DX is runing...
# SSTI is runing...
# date miss
# date miss
# HAYN is day noting
# date miss
# TEDU is day noting
# date miss
# date miss
# date miss
# AGEN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# RMNI is runing...
# date miss
# date miss
# CRAI is runing...
# date miss
# BZH is runing...
# date miss
# date miss
# date miss
# date miss
# RBB is runing...
# date miss
# date miss
# FNKO is runing...
# date miss
# MPAA is runing...
# date miss
# date miss
# XXII is day noting
# date miss
# date miss
# AGYS is runing...
# date miss
# date miss
# date miss
# REI is runing...
# date miss
# date miss
# date miss
# date miss
# CSWC is runing...
# STIM is runing...
# date miss
# ABEO is runing...
# PAR is runing...
# date miss
# date miss
# date miss
# ESTE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# PI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AUDC is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SMTS is runing...
# date miss
# DQ is runing...
# date miss
# date miss
# date miss
# LOOP is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MOFG is runing...
# PLUG is runing...
# date miss
# date miss
# ACRS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# NDLS is day noting
# date miss
# date miss
# date miss
# LQDA is runing...
# date miss
# date miss
# VYGR is runing...
# date miss
# date miss
# date miss
# CSV is runing...
# date miss
# ALBO is runing...
# date miss
# CLAR is runing...
# date miss
# date miss
# date miss
# date miss
# TGLS is runing...
# date miss
# WPRT is runing...
# CHMI is runing...
# LAC is day noting
# WNEB is runing...
# date miss
# date miss
# date miss
# date miss
# HIBB is runing...
# date miss
# date miss
# date miss
# date miss
# EXK is runing...
# BHR is runing...
# date miss
# DNN is runing...
# date miss
# date miss
# WEYS is day noting
# date miss
# date miss
# date miss
# OOMA is runing...
# GOGO is runing...
# LL is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# SGC is day noting
# CCRN is runing...
# date miss
# date miss
# date miss
# TPVG is runing...
# CYRX is runing...
# date miss
# date miss
# AMRS is runing...
# TNK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# VSTM is runing...
# date miss
# date miss
# date miss
# [12] USWS
# date miss
# date miss
# date miss
# date miss
# CVEO is day noting
# ACNB is runing...
# UUUU is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ASRT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SNCR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SRT is runing...
# date miss
# SILC is runing...
# date miss
# date miss
# date miss
# OBE is day noting
# BCOV is runing...
# date miss
# date miss
# ICD is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# STRO is runing...
# TNP is day noting
# date miss
# date miss
# date miss
# date miss
# CTV is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# RYI is runing...
# date miss
# [13] FNHC
# date miss
# date miss
# date miss
# SMMF is runing...
# TCS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# LND is runing...
# date miss
# date miss
# date miss
# date miss
# NC is runing...
# EPM is runing...
# date miss
# date miss
# SMBK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [14] CECE
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CDLX is runing...
# date miss
# date miss
# date miss
# IMV is runing...
# date miss
# date miss
# CUTR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GMRE is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# UEC is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# AI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# LQDT is day noting
# date miss
# ABUS is day noting
# BWFG is runing...
# KNDI is runing...
# date miss
# date miss
# date miss
# NWPX is runing...
# MCRB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DZSI is runing...
# MNKD is runing...
# BELFB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AVCO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# TWIN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# LAND is runing...
# ADES is day noting
# EIGR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# TSBK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FSBW is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# RICK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DBD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HSDT is day noting
# date miss
# date miss
# AVID is runing...
# KALA is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# APRN is day noting
# date miss
# date miss
# CVGI is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# III is runing...
# date miss
# date miss
# date miss
# date miss
# KINS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FBIZ is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# FSTR is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FPI is runing...
# OCUL is runing...
# date miss
# CWBR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# BCBP is day noting
# date miss
# date miss
# date miss
# XENE is runing...
# date miss
# date miss
# CELH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# FFNW is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PTGX is runing...
# AXON is runing...
# date miss
# date miss
# date miss
# CALA is day noting
# APPS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# LXU is runing...
# date miss
# OPRX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HNRG is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PEBK is runing...
# date miss
# NATR is runing...
# DRD is day noting
# date miss
# PTN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CGEN is runing...
# date miss
# date miss
# date miss
# date miss
# VBIV is runing...
# date miss
# date miss
# ASLN is day noting
# date miss
# date miss
# date miss
# CLFD is runing...
# date miss
# date miss
# KIRK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# OFS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# EQ is runing...
# date miss
# date miss
# PCYG is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ENZ is day noting
# EARN is runing...
# CBFV is runing...
# date miss
# HWBK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [15] CYBE
# date miss
# NTIC is day noting
# date miss
# IDEX is runing...
# date miss
# date miss
# date miss
# ARDX is runing...
# AUBN is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ITI is runing...
# date miss
# date miss
# GIFI is day noting
# date miss
# date miss
# date miss
# TGB is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SPRO is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HBIO is runing...
# date miss
# date miss
# date miss
# date miss
# MGI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# TPZ is day noting
# date miss
# LOV is runing...
# date miss
# date miss
# KODK is runing...
# date miss
# date miss
# date miss
# LIQT is runing...
# date miss
# date miss
# BLBX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ALPN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# CMCL is day noting
# date miss
# date miss
# CPHC is day noting
# date miss
# date miss
# ALIM is runing...
# FBIO is runing...
# FBIOP is runing...
# ICAD is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ORMP is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# EVK is runing...
# date miss
# date miss
# FAT is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NTIP is day noting
# TURN is day noting
# date miss
# date miss
# date miss
# PLX is runing...
# date miss
# EVGN is runing...
# date miss
# date miss
# date miss
# WISA is runing...
# date miss
# BKTI is runing...
# VFL is runing...
# date miss
# date miss
# date miss
# date miss
# EAST is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AP is runing...
# MARK is runing...
# date miss
# date miss
# CFBK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# POLA is day noting
# OPNT is runing...
# date miss
# date miss
# date miss
# date miss
# SOL is runing...
# date miss
# date miss
# BLPH is day noting
# date miss
# AGTC is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PPSI is runing...
# date miss
# GVP is runing...
# date miss
# date miss
# date miss
# date miss
# HDSN is runing...
# WFCF is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [18] WSTG
# date miss
# date miss
# VCNX is day noting
# date miss
# FUV is day noting
# NCTY is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# WLMS is runing...
# date miss
# date miss
# date miss
# date miss
# ADIL is day noting
# DXR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# GURE is day noting
# date miss
# COSM is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# LPTX is runing...
# date miss
# date miss
# date miss
# date miss
# INUV is day noting
# HYRE is day noting
# date miss
# SOLO is runing...
# date miss
# date miss
# date miss
# WYY is day noting
# date miss
# date miss
# date miss
# IDN is runing...
# VBLT is day noting
# date miss
# date miss
# WVVI is runing...
# LWAY is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MBRX is day noting
# WTT is day noting
# date miss
# LGL is runing...
# date miss
# date miss
# date miss
# date miss
# OSS is day noting
# date miss
# date miss
# date miss
# SLS is runing...
# date miss
# date miss
# DGLY is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [19] MN
# date miss
# date miss
# CFMS is day noting
# date miss
# SVT is runing...
# date miss
# date miss
# date miss
# PAVM is runing...
# PMTS is runing...
# date miss
# date miss
# date miss
# date miss
# AEMD is runing...
# date miss
# date miss
# ENSV is day noting
# date miss
# EQS is day noting
# date miss
# NOVN is day noting
# date miss
# date miss
# CVV is runing...
# VTSI is day noting
# date miss
# date miss
# ZDGE is day noting
# date miss
# BTCY is day noting
# XELB is day noting
# RIOT is day noting
# QRHC is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NAVB is runing...
# Abnormal detected : https://finance.yahoo.com/news/navidea-biopharmaceuticals-reports-third-quarter-130000552.html
# date miss
# date miss
# date miss
# date miss
# date miss
# BIOL is runing...
# date miss
# date miss
# DPSI is runing...
# date miss
# date miss
# TCON is day noting
# date miss
# DRIO is runing...
# AIRI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# ASTC is day noting
# date miss
# date miss
# CIDM is day noting
# date miss
# date miss
# date miss
# OESX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PXS is day noting
# date miss
# RVP is runing...
# date miss
# date miss
# LTBR is day noting
# date miss
# date miss
# BTN is runing...
# CGA is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# CPSH is runing...
# date miss
# date miss
# NBY is runing...
# DLPN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# SNGX is day noting
# date miss
# FSI is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# CODX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SNES is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AEY is day noting
# date miss
# LIVE is runing...
# date miss
# RCON is runing...
# ONTX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# BKYI is day noting
# EPIX is day noting
# date miss
# date miss
# date miss
# PED is day noting
# SGBX is runing...
# date miss
# date miss
# ELSE is runing...
# date miss
# SGRP is runing...
# CBAT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# YTEN is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MDGS is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NDRA is runing...
# SES is runing...
# SNOA is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ACHV is day noting
# SSNT is day noting
# VVPR is runing...
# date miss
# date miss
# DARE is day noting
# date miss
# date miss
# date miss
# ESEA is runing...
# date miss
# date miss
# date miss
# MICT is day noting
# JAGX is day noting
# DFFN is day noting
# date miss
# AYTU is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CREX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# UAVS is day noting
# date miss
# date miss
# IPDN is day noting
# [20] XSPA
# date miss
# ABIO is runing...
# INPX is runing...
# date miss
# date miss
# RSLS is day noting
# date miss
# date miss
# MTP is day noting
# OXBR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# IPWR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ZM is runing...
# SNOW is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PLTR is runing...
# CHPT is runing...
# date miss
# date miss
# date miss
# TRIN is runing...
# date miss
# date miss
# AAIC is runing...
# GMAB is day noting
# date miss
# SWAV is runing...
# date miss
# date miss
# date miss
# date miss
# NKLA is runing...
# date miss
# date miss
# date miss
# ONDS is runing...
# LYFT is runing...
# HLIO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GL is day noting
# date miss
# date miss
# MGNI is day noting
# date miss
# date miss
# PLMR is runing...
# date miss
# date miss
# FSR is runing...
# date miss
# BYND is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# IHRT is runing...
# date miss
# date miss
# FOUR is day noting
# date miss
# CNSP is runing...
# date miss
# EAR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# BKR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# FUBO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DOW is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DDOG is runing...
# [21] PING
# date miss
# date miss
# AZYO is day noting
# date miss
# date miss
# date miss
# VTRS is runing...
# RXT is day noting
# date miss
# CALT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# STLA is runing...
# date miss
# FSS is runing...
# BLU is runing...
# date miss
# U is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ABNB is runing...
# IAA is runing...
# date miss
# DASH is runing...
# date miss
# date miss
# date miss
# date miss
# NET is runing...
# date miss
# date miss
# date miss
# date miss
# CIXX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# DKNG is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# KLR is runing...
# FVRR is runing...
# CRSR is runing...
# date miss
# RVLV is runing...
# date miss
# date miss
# UBER is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SI is runing...
# date miss
# date miss
# PINE is day noting
# date miss
# date miss
# GOLD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PEAK is runing...
# date miss
# PINS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# LI is runing...
# date miss
# DRTT is day noting
# date miss
# VVNT is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AZEK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# CNEY is runing...
# J is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [22] CSCW
# date miss
# date miss
# GEG is day noting
# date miss
# date miss
# date miss
# date miss
# BIVI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ESSC is day noting
# ICMB is runing...
# date miss
# date miss
# date miss
# date miss
# CUBA is day noting
# date miss
# date miss
# KERN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# POWW is day noting
# date miss
# date miss
# date miss
# date miss
# ATEX is runing...
# date miss
# date miss
# CRKN is day noting
# date miss
# date miss
# ACCD is runing...
# ACI is runing...
# date miss
# date miss
# date miss
# ASO is day noting
# ASAN is day noting
# date miss
# date miss
# CRWD is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NCNO is day noting
# date miss
# date miss
# date miss
# date miss
# XPEV is runing...
# date miss
# date miss
# HCDI is day noting
# ELDN is day noting
# date miss
# date miss
# TBLT is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# SRGA is day noting
# VIRI is runing...
# date miss
# MASS is runing...
# date miss
# date miss
# date miss
# STRRP is day noting
# date miss
# FHTX is day noting
# date miss
# JFIN is day noting
# date miss
# REPX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# HARP is day noting
# date miss
# INMB is day noting
# date miss
# date miss
# date miss
# date miss
# SMTI is day noting
# date miss
# date miss
# date miss
# date miss
# BMBL is runing...
# [23] GBOX
# date miss
# VFF is day noting
# date miss
# YALA is runing...
# date miss
# date miss
# TIGR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# NEXI is day noting
# date miss
# date miss
# date miss
# date miss
# STRR is day noting
# date miss
# NMTR is day noting
# date miss
# date miss
# date miss
# LGVN is day noting
# date miss
# PBTS is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GAN is runing...
# date miss
# HOOK is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# GHSI is day noting
# date miss
# date miss
# PPTA is day noting
# TRVI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FDMT is runing...
# date miss
# date miss
# date miss
# IMNM is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# NLSP is day noting
# XCUR is runing...
# date miss
# NYC is runing...
# date miss
# date miss
# date miss
# date miss
# TFFP is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# AKUS is runing...
# date miss
# date miss
# date miss
# date miss
# JUPW is day noting
# date miss
# date miss
# date miss
# date miss
# GATO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# BATL is day noting
# date miss
# date miss
# date miss
# date miss
# RPTX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# CSTL is runing...
# BEAM is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# MDWT is runing...
# STSA is runing...
# date miss
# COGT is day noting
# IKT is runing...
# date miss
# date miss
# date miss
# FBRX is runing...
# date miss
# date miss
# VERB is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# OLB is day noting
# BNTX is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# BFI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# VRDN is day noting
# CAN is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# REKR is day noting
# date miss
# date miss
# FINV is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ONCT is day noting
# date miss
# date miss
# date miss
# AUVI is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# RVPH is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# QH is runing...
# date miss
# date miss
# date miss
# date miss
# VTRU is day noting
# BEEM is day noting
# date miss
# date miss
# date miss
# date miss
# FGF is runing...
# NLTX is day noting
# date miss
# date miss
# NFE is runing...
# date miss
# date miss
# SHYF is day noting
# date miss
# date miss
# MTCR is day noting
# date miss
# KBNT is day noting
# date miss
# AIM is day noting
# date miss
# SNDL is runing...
# date miss
# date miss
# PRLD is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# XM is runing...
# date miss
# date miss
# XGN is day noting
# VISL is day noting
# date miss
# date miss
# date miss
# DCBO is runing...
# LHDX is day noting
# date miss
# date miss
# date miss
# date miss
# SHLS is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# SANA is day noting
# date miss
# IPHA is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# STOK is runing...
# date miss
# date miss
# EVAX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# IGIC is runing...
# date miss
# date miss
# date miss
# SONM is day noting
# date miss
# PSHG is day noting
# date miss
# INVO is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# VS is day noting
# date miss
# date miss
# GRCL is day noting
# date miss
# date miss
# date miss
# SAVA is day noting
# CGEM is day noting
# DUOT is day noting
# LUMO is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# PDSB is day noting
# date miss
# date miss
# date miss
# AMPG is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# RCAT is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# OMQS is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# [24] BLSA
# date miss
# date miss
# date miss
# KULR is day noting
# date miss
# date miss
# PTMN is runing...
# TMBR is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# ADN is runing...
# GOEV is runing...
# RIDE is runing...
# OPEN is runing...
# [25] PIPP
# date miss
# date miss
# date miss
# date miss
# PRCH is runing...
# date miss
# date miss
# date miss
# date miss
# date miss
# FORA is day noting
# date miss
# date miss
# HPK is day noting
# date miss
# date miss
# date miss
# [26] HIGA
# date miss
# date miss
# [27] LFTR
# date miss
# date miss
# YMTX is day noting
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# date miss
# VIRX is day noting
# date miss
# [28] HAACU
# 28
# done!

# %%
################### 시장 시간대 구역 ############################
# 시간 관련 라이브러리에서 종종 1자리수 숫자에 0 안붙이는거 해결...
def date_zero_padding(m):
    if m < 10:
        m = '0' + str(m)
    else:
        m = str(m)
    return m


# 노멀한 메타 데이터에서 시간 추출
def yahoo_market_time(url):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    datetimes = soup.find("time")
    datetimes = datetimes['datetime']
    dt = datetimes.split('T')
    d = dt[0]
    t = dt[1].split('.')
    t = t[0]
    dt = d + ' ' + t
    dt = dtime.strptime(dt, '%Y-%m-%d %H:%M:%S')
    one_hour_ago = dt - datetime.timedelta(hours=4)
    date_time = one_hour_ago  # html에서 GMT 기준으로 나오기에, -4 시간 빼야 미국 현재 시각, 표기로는 GMT+9 를 따름
    return date_time


def yahoo_market_search_time(url, market_time):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    if market_time == 0:
        market_time = ['00:10:00', '00:20:00']
    datetimes = soup.find("time")
    datetimes = datetimes['datetime']
    dt = datetimes.split('T')
    d = dt[0]
    t = dt[1].split('.')
    t = t[0]
    dt = d + ' ' + t
    dt = dtime.strptime(dt, '%Y-%m-%d %H:%M:%S')
    one_hour_ago = dt - datetime.timedelta(hours=4)
    date_time = one_hour_ago  # html에서 GMT 기준으로 나오기에, -4 시간 빼야 미국 현재 시각, 표기로는 GMT+9 를 따름

    start_hms = market_time[0]
    end_hms = market_time[1]
    # start_hms = '16:00:00'
    # end_hms = '16:30:00'
    usa_est = datetime.datetime.now(pytz.timezone('America/New_York'))
    ymd_date = str(usa_est.year) + '-' + str(usa_est.month) + '-' + str(usa_est.day)

    limit_start = ymd_date + ' ' + start_hms
    limit_end = ymd_date + ' ' + end_hms

    limit_start = dtime.strptime(limit_start, '%Y-%m-%d %H:%M:%S')
    limit_end = dtime.strptime(limit_end, '%Y-%m-%d %H:%M:%S')

    return date_time, limit_start, limit_end


###################핀 비즈 구역 ############################

def finviz_news_crawler(db, category, ticker_list, ymd_date):
    news_info_list = []
    error_cnt = 0

    for t in range(len(ticker_list)):
        ticker = ticker_list[t][0]
        # ticker, s_name, s_code = ticker_list[1][0], ticker_list[1][1], ticker_list[1][2]
        try:
            fin_dic = finviz_news_crawling(ticker, ymd_date)
        except:
            error_cnt += 1
            print('[' + str(error_cnt) + ']', ticker)

            continue
        if len(fin_dic) == 0:
            print(ticker, 'is noting' )
            continue  # 오늘 데이터 없으면 다음 티커 를 탐색
        try:
            if len(fin_dic[ymd_date]) == 0:
                print(ticker, 'is day noting' )
                continue  # 오늘 데이터 없으면 다음 티커 를 탐색
        except:
            print('date miss')
            continue
        print(ticker, 'is runing...' )
        p_list = fin_dic[ymd_date]
        
        for u in range(len(p_list)):
            url = p_list[u][-1]
            news_checking = finviz_news_check(db, url, ticker)
            if news_checking == 1:
                continue  # 중복된 url + 종목의 뉴스가 있다면 스킵

            try:
                news_info = fyahoo_stock_news_inlink_extract(url, headers)
                # [news_info] ... + 분류명 (종목 뉴스) , 티커, 종목명, 종목 코드
                # [news_info] ... + categroy ('stock_news') , ticker, stock_name, stock_code
                # category column 변경 필요 ->  market_time 으로, 기존의 시황 뉴스는 category = 'market_news' 로

                news_info_add = news_info + [category] + [ticker]
                url, title, body = news_info_add[0], news_info_add[1], news_info_add[2]
                w_date, n_date, press = news_info_add[3], news_info_add[4], news_info_add[5]
                category, ticker = news_info_add[6], news_info_add[7]

                news_input = stock_news_insert(db, url, title, body, w_date, n_date, press, category, ticker)
                nadd_info = [url, title, body, w_date, n_date, press, category, ticker]
                # 나중엔 삭제 똔느 스킵
                news_info_list.append(nadd_info)
                # print(url,nadd_info[6:])  # 확인용

                ## db 저장하는 함수 필요 : 최근 글 중복 처리하는 방법도 필요

            except:
                print('Abnormal detected :', url)
                continue
            time.sleep(2)
        # print(ticker,len(news_info_list))
    print(error_cnt)
    return news_info_list


def finviz_news_crawling(name, ymd_date):
    c_press_list = ['Bloomberg', 'Reuters', 'Yahoo Finance', 'Investing.com', 'Zacks', 'The Telegraph',
                    'Insider Monkey',
                    'Benzinga', 'Simply Wall St.', 'Business Wire', 'The Independent', 'Fortune', 'CoinDesk', 'Variety',
                    'PR Newswire', 'WWD', 'Skift', 'LA Times', 'The Guardian', 'Poets & Quants', 'GuruFocus.com']

    url = "https://finviz.com/quote.ashx?t=" + name + "&p=d"

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    date_find = soup.find_all('table', {'class': 'fullview-news-outer'})
    date_finding = date_find[0].find_all('td', {'align': 'right'})

    news_link = date_find[0].find_all('div', {'class': 'news-link-left'})
    news_press = date_find[0].find_all('div', {'class': 'news-link-right'})

    purl_list = []

    date_dic = {}  # 만약을 위해  view에 보이는 날짜 전부를 수집, 평소엔 가장 상단의 키만을 사용 -> 다음 키 생성시 break

    for i in range(len(news_link)):
        press_name = news_press[i].find('span').text.lstrip()
        press_title = news_link[i].text
        press_url = news_link[i].find('a')['href']

        date_time = date_finding[i].text
        date_split_time = date_time.split(' ')
        if len(date_split_time) >= 2:
            ymdate = date_split_time[0].split('-')
            m, d, y = ymdate[0], ymdate[1], ymdate[2]
            m = strptime(m, '%b').tm_mon
            if m < 10:
                m = '0' + str(m)
            else:
                m = str(m)
            ymd_str = '20' + y + '-' + m + '-' + d  # dict 키 용
            dtime_pro = date_split_time[1]

            #if ymd_str != ymd_date:
            #    break  # 오늘 아니면 탈출

            date_dic[ymd_str] = []

            #if len(date_dic) > 2:
            #    del date_dic[ymd_str]
            #    break  # 딱 하루치만 보기

        else:
            dtime_pro = date_split_time[0]

        if press_url.find('finance.yahoo') == -1:
            continue
        if press_name not in c_press_list:
            continue

        date_dic[ymd_str].append([dtime_pro, press_name, press_title, press_url])
    return date_dic


def finviz_news_check(db, url, ticker):
    # db에 url 가 있다면 break! ]
    checking_sql = "SELECT * FROM US_Stock_Market_News WHERE url = '" + url + "' and symbol ='" + ticker + "'"

    cur = db.cursor()
    cur.execute(checking_sql)
    result = cur.fetchall()

    if len(result) >= 1:
        result = 1  # 1이면 contine
    else:
        result = 0
    return result


def stock_info_load(db, select_ticker):
    checking_sql = "SELECT symbol, name, ISIN FROM Company_Information_Data"

    cur = db.cursor()
    cur.execute(checking_sql)
    result = cur.fetchall()

    df_db = pd.DataFrame(result, columns=['symbol', 'name', 'ISIN'])

    target_sname = []
    if select_ticker != 0:
        # 선택한 것만 하는 것
        for s in range(len(select_ticker)):
            ticker = select_ticker[s]
            stock_info = df_db[df_db['symbol'] == ticker]
            list_con = stock_info.values.tolist()
            target_sname.append(list_con[0])

        df = pd.DataFrame(target_sname, columns=['symbol', 'name', 'ISIN'])
    else:
        df = df_db
    ticker_list = []

    for d in range(len(df)):
        ticker = df['symbol'].iloc[d]
        s_name = df['name'].iloc[d]
        s_code = df['ISIN'].iloc[d]
        ticker_list.append([ticker, s_name, s_code])

    return ticker_list


###################야후 파이낸스 구역 ############################

def yahoo_crawler(db, mtime):
    ## 미국 주식 거래시간
    us_market_time_dic = {'BMO(UST)': ['07:30:00', '09:30:00'], 'AMO(UST)': ['10:30:00', '11:30:00'],
                          'AMC(UST)': ['17:00:00', '18:30:00'], 'BMO(DST)': ['06:30:00', '09:00:00'],
                          'AMO(DST)': ['09:30:00', '10:30:00'], 'AMC(DST)': ['16:00:00', '17:30:00']}
    usa_est = datetime.datetime.now(pytz.timezone('America/New_York'))

    c_press_list = ['Bloomberg', 'Reuters', 'Yahoo Finance', 'Investing.com', 'Zacks',
                    'Fortune' 'LA Times', 'Kiplinger', 'Business Insider', 'USA TODAY', 'Insider']

    o_press_list = ["Investor's  Daily", 'TheStreet.com']  # 아웃링크 뉴스 언론사
    c_press_list = c_press_list + o_press_list
    # c_press_list = ['Bloomberg', 'Reuters', 'Kiplinger', 'Business Insider', 'Yahoo Finance', 'USA TODAY', 'LA Times']
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}

    url_list = yahoo_crawling(db)
    market_time = us_market_time_dic[mtime]
    # c = category
    # 임시 리턴
    pre_urls = []
    data_list = []
    error_list = []
    for u in range(len(url_list)):
        source = url_list[u][0]
        w_press = url_list[u][1]
        w_press = w_press.replace('News', '').lstrip()
        pre_urls.append([w_press, source])
        if w_press in c_press_list:  # 검증한 언론사들이 포함되어 있다면,
            # 시간대 좁히기
            date_time, limit_start, limit_end = yahoo_market_search_time(source, market_time)
            if date_time >= limit_start and date_time < limit_end:  # 시황 마감후 1시 30분 까지가 아니라면
                try:
                    news_parsing = fyahoo_stock_news_inlink_extract(source, headers)
                except:
                    error_news = [w_press, source]
                    print('error :', error_news)
                    error_list.append(error_news)
                    continue
                title, body = news_parsing[1], news_parsing[2]
                # 시황 뉴스의 경우, 시간대 체크 -> 범용으로 쓰이기 위해 따로 둠 v1 -> v2
                if title_classifier(title) == 0:
                    continue
                w_date, n_date, press = news_parsing[3], news_parsing[4], news_parsing[5]
                in_data = [source, title, body, w_date, n_date, press, mtime]
                # print(in_data)
                data_list.append(in_data)
                market_news_insert(db, source, title, body, w_date, n_date, press, mtime)

    return pre_urls, data_list, error_list


## 220614-15 임시 수집 타이밍  :  야후 파이낸스
def yahoo_crawling(db):
    url = 'https://finance.yahoo.com/topic/stock-market-news/'
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # chrome_options = webdriver.ChromeOptions()
    # chrome_options.add_argument('--headless')
    # chrome_options.add_argument('--no-sandbox')
    # chrome_options.add_argument("--single-process")
    # chrome_options.add_argument("--disable-dev-shm-usage")

    path = 'chromedriver_107.exe'
    driver = webdriver.Chrome(path)  # , chrome_options=chrome_options)
    count = 200  # 페이지 한번에 보여줄수 있는양
    url_list = []
    driver.get(url)
    # 스크롤 전 높이
    before_h = driver.execute_script("return window.scrollY")
    # 무한 스크롤
    while True:
        # 맨 아래로 스크롤을 내린다.
        time.sleep(2)
        driver.find_element_by_css_selector("body").send_keys(Keys.END)
        # 스크롤 사이 페이지 로딩 시간
        time.sleep(2)
        # 스크롤 후 높이
        after_h = driver.execute_script("return window.scrollY")
        if after_h == before_h:
            break
        before_h = after_h
    #### 페이지내 url 긁어오기
    url_list = []

    for i in range(count):  # 페이지 한계로 200 개 정도 확인
        press_i = '//*[@id="Fin-Stream"]/ul/li[' + str(i + 1) + ']/div/div/div[2]'
        href_i = press_i + '/h3/a'
        href_xpath = driver.find_elements_by_xpath(href_i)
        press_xpath = driver.find_elements_by_xpath(press_i)
        if len(href_xpath) == 0:
            press_i = '//*[@id="Fin-Stream"]/ul/li[' + str(i + 1) + ']/div/div/div[1]'
            href_i = press_i + '/h3/a'
            href_xpath = driver.find_elements_by_xpath(href_i)
            press_xpath = driver.find_elements_by_xpath(press_i)
        if len(href_xpath) == 0:
            continue

        href = href_xpath[0].get_attribute('href')
        title = href_xpath[0].text
        press = press_xpath[0].text
        press = press.split('•')
        press = press[0].replace('Business', '').lstrip()
        url_list.append([href, press])

    driver.quit()

    return url_list


################### 파싱 함수구역 ############################

# 인링크 방식 뉴스 내용 파싱 : 야후 버전 실상 버전 2이나 구별을 위해 inlink만 사용
def fyahoo_stock_news_inlink_extract(url, headers):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    news_data = []

    date_time = yahoo_market_time(url)
    now = dtime.now()
    title = soup.find("meta", property="og:title")
    title = title['content']

    press = soup.find("img", {'class': "caas-img"})
    press = press['alt']

    conts = soup.find_all('p')  # .text
    content = soup.find_all('div', {'class': 'caas-body'})
    body_p = content[0]('p')
    body = body_p_clean(body_p, press)

    if press == 'USA TODAY':
        headline = context_preprocessing(conts[1:3])
        # body = context_preprocessing(conts)
    if press == 'Reuters':
        # body_p = period_index(body_p)
        body = body_p_clean(body_p, press)
        body = body.split('(Reporting')
        bodys = body[0]
        body = press_local_find(bodys, press)
    if press == 'LA Times':
        body = body.split('This story originally')
        body = body[0]
    if press == 'Bloomberg':
        body = body.split('(Updates')
        body = body[0]

    if press == 'Investing.com':
        body = body.split('Related Articles')
        body = body[0]

    if press == 'Zacks':
        body = body.split('Want the latest')
        body = body[0]

    if press == "Investor's Business Daily":  # 아웃링크
        out_url = soup.find("meta", property="og:url")
        out_url = out_url['content']
        response = requests.get(out_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        content = soup.find_all('div', {'class': 'single-post-content post-content drop-cap'})
        body_p = content[0]('p')
        body = body_p_clean(body_p, press)

    if press == 'TheStreet.com':
        out_url = soup.find("meta", property="og:url")
        out_url = out_url['content']
        response = requests.get(out_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        if out_url.find('realmoney') >= 1:
            content = soup.find_all('div', {'class': 'article__body article-author-rail__body'})
            body_p = content[0]('p')
        elif out_url.find('aap.') >= 1:
            content = soup.find_all('div', {'class': 'article__body article-back-header__body'})
            body_p = content[0]('div')
        else:
            content = soup.find_all('div', {'class': 'm-detail--body'})
            body_p = content[0]('p')
        # body_p = content[0]('p')
        body = body_p_clean(body_p, press)

    # body = body_split(body)
    # headline_token = sent_tokenize(body)
    # if len(headline_token) <= 2:
    #    headline = body
    # else:
    #    headline = headline_token[0] + ' ' + headline_token[1]

    inlink_news = [url, title, body, date_time, now, press]

    return inlink_news


################### 기타 전처리 함수구역 ############################

# 만일을 위해서 함수화 했는데.. 생각보다 전처리가 잘 되었기에 ...
def clean_text(text):
    # cleaned_text = text.replace("\'", "'")
    cleaned_text = text.replace('  \n ', '')
    cleaned_text = cleaned_text.replace('(Bloomberg) -- ', '')

    return cleaned_text


# 날짜를 datetime format으로 변환 하기 위한 함수
def dt_format(dt_texts):
    a = dt_texts.find('(')
    b = dt_texts.find(')')

    result = dt_texts[a + 1:b]
    result = result.replace(',', '')
    dt = result.split(' ')
    dt_pm = dt[3].find('PM')  # 있으면 + 없으면 -1 반환

    if dt_pm != -1:  ## 오후 타임이면,
        pre_dt = dt[3].replace('PM', '')
        pre_dt = pre_dt.split(':')
        if int(pre_dt[0]) == 12:
            t, m = pre_dt[0], pre_dt[1]
        else:
            pm_time = str(int(pre_dt[0]) + 12)
            t, m = pm_time, pre_dt[1]

    else:  # 오전타임이면
        pre_dt = dt[3].replace('AM', '')
        pre_dt = pre_dt.split(':')
        t, m = pre_dt[0], pre_dt[1]

    dt_mon = strptime(dt[0], '%b').tm_mon

    if dt_mon < 10:
        dt_mon = '0' + str(dt_mon)

    str_datetimed = dt[2] + '-' + str(dt_mon) + '-' + dt[1] + ' ' + t + ":" + m + ":" + '00'
    currdate = datetime.datetime.strptime(str_datetimed, '%Y-%m-%d %H:%M:%S')

    return currdate


# 본문 리스트화된 것을 문자열로 연결
def context_preprocessing(cp):
    texts_list = []
    texts = ''
    for i in range(len(cp)):
        texts = texts + cp[i].text + ' '
        texts_list.append(cp[i].text)
    cleans = clean_text(texts)
    return cleans


### 뉴스 분류  : 키워드 방식인데, 아무래도 일부 키워드는 해결 불가하기에, 모델 구축 방향으로 가야함, 데이터가 쌓이면

# 맞는 뉴스인지 아닌지 판단 하기  : 키워드 기반
def title_classifier(title):
    # headline  = data[2]
    t_check = title_key_check(title)
    # h_check= news_close_time(headline )
    classifier = 0
    if t_check >= 1:
        classifier = 1  # 제목에 시황 뉴스를 암시하는 'stock market today' 가 있다면,
    # 제목엔 없지만 헤드라인에 관련 키워드가 한개이상이라면,

    return classifier


# 규칙 제목 한정 제목 분류
def title_key_check(sentence):
    title_key = ['smtody', 'cloftrade', 'wallst', 'pts', 'usastocks', 'liveupdate', 'usatocksturn',
                 'marketshows', 'ustocksdrop', 'ustockshigh', 'stockmarketcloses', 'marketswrap', 'stockmarket',
                 'stocksendlower']

    #  'markets', 'market']  # 'futures',
    un_key = ['emerging', 'EMERGING', 'global', 'GLOBAL']
    sentence = sentence.lower()
    sentence = sentence.replace("stock market today", title_key[0])
    sentence = sentence.replace("stock market today:", title_key[0])
    sentence = sentence.replace("close of trade", title_key[1])
    sentence = sentence.replace("us stocks-wall", title_key[2])
    # sentence = sentence.replace("wall st", title_key[2])
    sentence = sentence.replace("pts;", title_key[3])
    sentence = sentence.replace("u.s. stocks", title_key[4])
    sentence = sentence.replace("live updates:", title_key[5])
    sentence = sentence.replace("us stocks turn", title_key[6])
    sentence = sentence.replace("market shows", title_key[7])
    sentence = sentence.replace("us stocks drop", title_key[8])
    sentence = sentence.replace("us stocks high", title_key[9])
    sentence = sentence.replace("stock market closes", title_key[10])
    sentence = sentence.replace("markets wrap", title_key[11])
    sentence = sentence.replace("stock market", title_key[12])
    sentence = sentence.replace("stocks end lower", title_key[13])

    word_count = 0
    for t in range(len(title_key)):
        if title_key[t] in sentence:
            word_count += 1
            # print(title_key[t])
        # 제거
        if title_key[t] in un_key:
            word_count = 0
            break

    return word_count


# 야후 파이낸스 전용 전처리
def body_p_clean(body_p, press):
    # body_p = soup.find_all('p')
    body = ''

    for s in range(len(body_p)):
        body_text = body_p[s].text
        if press == 'Yahoo Finance':
            if body_text == '—':
                break
        if press == 'Bloomberg':
            if s == 0:
                body_text = bloomberg_match(body_text)
            else:
                if body_p[s].find('a') is not None:
                    continue
                more_finding = body_text.find('Most Read')
                if more_finding == 0:
                    continue
                read_finding = body_text.find('Read more:')
                if read_finding == 0:
                    continue
                body_text = bloomberg_end_match(body_text)
                if body_text.find('More market') != -1:
                    break
                if len(body_text) == 0:
                    continue
                if body_text.find('this week:') != -1:
                    break
                if body_text.find('Read:') != -1:
                    break

        # 여기서부터 언론사별 불필요한 패턴 자르기

        if press == 'Kiplinger':
            if body_text.find('SEE MORE') != -1:
                continue
            if body_text.find('Sign up') != -1:
                continue
            if body_text.find('YCharts') != -1:
                break

        if press == 'Zacks':
            # check_tag = body_p[s].find('strong')
            # if check_tag != None:
            #    continue
            zacks_finding = body_text.find('Zacks Investment Research?')

            if zacks_finding >= 0:
                continue

            infull_finding = body_text.find('[In full disclosure,')
            if infull_finding >= 0:
                continue

        if press == 'Yahoo Finance':
            check_tag = body_p[s].find('em')
            if check_tag != None:
                continue
            yahoo_click_finding = body_text.find('Click here for')
            if yahoo_click_finding >= 0:
                continue
            yahoo_read_finding = body_text.find('Read the latest')
            if yahoo_read_finding >= 0:
                continue

        if press == 'Benzinga':
            see_benzinga_finding = body_text.find('See more')
            if see_benzinga_finding >= 0:
                break

        if press == 'Insider Monkey':
            insider_monkey_c_finding = body_text.find('Click to continue')
            if insider_monkey_c_finding >= 0:
                break
            insider_monkey_s_finding = body_text.find('Suggested Articles:')
            if insider_monkey_s_finding >= 0:
                break

        if press == 'Business Wire':
            business_w_finding = body_text.find('NOTE TO')
            if business_w_finding >= 0:
                break
            business_c_finding = body_text.find('businesswire.com')
            if business_c_finding >= 0:
                break

            local_date_press = '[A-Z]+\s[A-Z]+,\s[A-Z]{1}[a-z]+\s[0-9]{2},\s[0-9]{4}[-]{1,2}[(][A-Z]{8}\s[A-Z]{4}[)][-]{1,2}'
            body_text = re.sub(local_date_press, '', body_text)

        if press == 'Fortune':
            fortune_finding = body_text.find('featured on Fortune.com')
            if fortune_finding >= 0:
                break

        if press == 'Simply Wall St.':
            sw_st_finding = body_text.find('free platform')
            if sw_st_finding >= 0:
                break

        if press == 'Variety':
            variety_finding = body_text.find('Best of Variety')
            if variety_finding >= 0:
                break

        if press == 'PR Newswire':
            pr_newswire_finding = body_text.find('Trademarks')
            if pr_newswire_finding >= 0:
                break

        if press == 'Skift':
            skift_finding = body_text.find('Subscribe to Skift')
            if skift_finding >= 0:
                break

        if press == 'Poets & Quants':
            pq_finding = body_text.find('MISS POLL')
            if pq_finding >= 0:
                break

        if press == 'ACCESSWIRE':
            accwire_finding = body_text.find('View additional')
            if accwire_finding >= 0:
                break

        if press == 'InvestorPlace':
            inplace_finding = body_text.find('More From InvestorPlace')
            if inplace_finding >= 0:
                break

        if press == 'GuruFocus.com':
            gf_finding = body_text.find('appeared on GuruFocus')
            if gf_finding >= 0:
                break

        if press == 'Business Insider':
            binsider_finding = body_text.find('Read the ')
            if binsider_finding >= 0:
                break

        if press == "Investor's Business Daily":
            invest_bd_finding = body_text.find('YOU MAY ALSO LIKE:')
            if invest_bd_finding >= 0:
                break
            invest_plz_finding = body_text.find('Please follow')
            if invest_plz_finding >= 0:
                break
            invest_follow_finding = body_text.find('Follow')
            if invest_follow_finding >= 0:
                continue

        if press == "TheStreet.com":
            thestreet_finding = body_text.find('Updated at')
            if thestreet_finding >= 0:
                continue

        if s == 0:  # 첫 빈 공간 고려하기
            body += body_text
        else:
            body = body + ' ' + body_text
        body = body.replace('\n', '')
        body = body.replace('\xa0', ' ')
        body = body.strip()

    return body


def body_split(text):
    tlink = ''
    tokenized_text = sent_tokenize(text)

    for d in range(len(tokenized_text)):
        tokend = tokenized_text[d]
        report_kill = reporter_match(tokend)
        report_kill = report_kill.lstrip()
        site_kill = investing_match(report_kill)
        tokend = site_kill.strip()
        if len(tokend) == 0:
            continue
        if d == 0:
            tlink = tokend
        else:
            tlink = tlink + ' ' + tokend

    return tlink


def reporter_match(text):
    # 기자 이름 지우기
    by_ = 'By'
    name_ = '[a-zA-Z]+'
    reporter_by = re.compile(by_)
    reporter_first_name = re.compile(name_)
    reporter_last_name = re.compile(name_)

    reporter_pattern = re.compile(by_ + ' ' + name_ + ' ' + name_)
    reporter = reporter_pattern.match(text)
    if reporter != None:
        reporter = reporter.group(0)
        text = text.replace(reporter, '')

    return text


def reporter_match_and(text):
    # 기자 이름 지우기
    by_ = 'By'
    name_ = '[a-zA-Z]+'
    reporter_by = re.compile(by_)
    reporter_first_name = re.compile(name_)
    reporter_last_name = re.compile(name_)

    reporter_pattern = re.compile(by_ + ' ' + name_ + ' ' + name_)
    reporter = reporter_pattern.match(text)
    if reporter != None:
        reporter = reporter.group(0)
        text = text.replace(reporter, '')

    return reporter


def investing_match(text):
    # 언론사 이름 지우기
    site_ = 'Investing.com'
    spect_ = '[–|-]{1,3}'

    site_pattern = re.compile(site_ + ' ' + spect_)
    site_name = site_pattern.match(text)
    # print(site_name)
    if site_name != None:
        site_name = site_name.group(0)

        text = text.replace(site_name, '')
    return text


def bloomberg_match(text):
    # 언론사 이름 지우기
    site_pattern = '(Bloomberg)'
    site_name = text.replace(site_pattern, '').lstrip()
    spect_pattern = re.compile('[-]+')

    doc = spect_pattern.match(site_name)
    if doc != None:
        doc = doc.group(0)
        text = site_name.replace(doc, '').lstrip()
    return text


def bloomberg_end_match(text):
    # 언론사 이름 지우기
    # text =  '©2022 Bloomberg L.P.'
    c_spect = '©[0-9]+\s[a-zA-Z]+\s[a-zA-Z]+.[a-zA-Z]+.'
    c_pattern = re.compile(c_spect)
    doc = c_pattern.match(text)

    if doc != None:
        doc = doc.group(0)
        text = text.replace(doc, '').strip()
    return text


def period_index(body_p):
    period_index = ''
    by_ = 'By'
    name_ = '[a-zA-Z]+'
    reporter_pattern = re.compile(by_ + ' ' + name_ + ' ' + name_)

    for r in range(len(body_p)):
        text = body_p[r].text
        report_split = reporter_pattern.match(text)
        if report_split != None:
            rs_ = body_p.index(body_p[r])
            period_index = rs_

    body_p = body_p[period_index + 1:]

    return body_p


# 로이터 용 언론사명 본문에서 끄집어서 짜르기
def press_local_find(text, press):
    # 본문내 불필요한 요일 언론사 이름 지우기
    # press = 'Reuters'
    spect_p = '(' + press + ')' + ' ' + '-'
    dt_press = text.find(spect_p)
    text = text[dt_press + len(spect_p):]
    text = text.lstrip()

    return text


# 220722 로이터 전처리 최신 버전
def reuters_preprocess(body_p):
    # body_list = []
    texts = ''
    cnt = 0
    for i in range(len(body_p)):
        text = body_p[i].text
        if text.find('(Updates with') >= 0:
            continue
        if text.find('For a Reuters') >= 0:
            continue
        if text.find('*') >= 0:
            continue
        reporter_name = reporter_match_and(text)
        # print(len(str(reporter_name)),reporter_name )
        if len(str(reporter_name)) > 5:
            continue
        if text == '':
            continue
        text = reuters_first_del(text)
        if text.find('Reporting') >= 0:
            text = text.split('(Reporting')
            text = text[0]
        if cnt == 0:
            texts = text
        else:
            texts = texts + ' ' + text
        # print(text)
        cnt += 1
        # body_list.append(text)
    return texts


def reuters_first_del(text):
    text = text.replace('NEW YORK,', '')
    text = text.lstrip()
    c_spect = '[a-zA-Z]+\s[0-9]+\s[^a-zA-Z0-9]{1}[Reuters]+[^a-zA-Z0-9]{1}'
    c_pattern = re.compile(c_spect)
    doc = c_pattern.match(text)

    if doc != None:
        doc = doc.group(0)
        text = text.replace(doc, '').strip()

    text = text.lstrip('-')
    text = text.lstrip()
    return text


# 220927 인베스팅 본문 오류 해결 함수
def conts_clean(conts):
    conts_del = ['Position added successfully to: \n']
    conts_full = ''

    for c in range(len(conts)):
        page_line = conts[c].text
        if page_line in conts_del:
            continue
        page_line = reporter_match(page_line)
        page_line = investing_match(page_line)
        conts_full += page_line + ' '
    conts_full = conts_full.strip()

    return conts_full


## 그외 기타 전처리 함수
# close_time_headline_keywords = ['usastocks', 'usastock', 'djia' , 'nasdaq', 'nyse','gspc','point']

def news_close_time(content):
    headline_keywords = ['usastocks', 'usastock', 'djia', 'nasdaq', 'nyse', 'gspc', 'point']
    checking_text = market_preprocessing(content)
    word_count = 0
    ## 내용 검사
    for i in range(len(checking_text)):
        word = checking_text[i]
        if word in headline_keywords:
            word_count += 1

    return word_count  # 1 이상이면 맞다는 것.


def market_preprocessing(sentence):
    stop_words = set(stopwords.words('english'))
    sentence = sentence.lower()
    sentence = sentence.replace("standard & poor's 500", 'gspc')
    sentence = sentence.replace('s&p 500', 'gspc')
    sentence = sentence.replace('s&p', 'gspc')
    sentence = sentence.replace('u.s. stock', 'usastock')
    sentence = sentence.replace('dow jones industrial average', 'djia')
    sentence = sentence.replace('%', ' ')
    sentence = sentence.replace('%,', ' ')
    word_tokens = word_tokenize(sentence)  # 월스트리트저널 기반 분해 -> s&p 500 을 산산조각냄
    result = []
    for w in word_tokens:
        if w not in stop_words:
            result.append(w)
    lemm = WordNetLemmatizer()
    wpos = []
    # 이건 필요없을 듯
    for w in result:
        wn = lemm.lemmatize(w, pos='n')
        wpos.append(wn)
    tagged_list = pos_tag(wpos)

    sw = ['.', ',', ':', 'CD', '(', ')', '``', "''", 'POS']
    removed_list = []
    for word in tagged_list:
        if word[1] not in sw:
            removed_list.append(word[0])
    removed_list = set(removed_list)
    removed_list = list(removed_list)

    return list(removed_list)


# 본문 리스트화된 것을 문자열로 연결
def invest_context_end_kill(cp):
    texts_list = []
    texts = ''
    con = 'continue reading'
    e_num_pattern = re.compile('^©[0-9]{1,4}\s[a-zA-Z]+')  # \s[a-zA-Z]+

    if cp[-1].text.lower().find(con) >= 0:
        del cp[-1]
    if cp[0].text == '\n':
        del cp[0]

    for i in range(len(cp)):
        m = e_num_pattern.match(cp[i].text)
        if m != None:
            pm = m.group(0)
            if pm.find(pm) >= 0:
                del cp[i]
                break

    return cp


###### 데이터 불러오는 것 ###########################################

def korean_like_data_split(df):
    used_dk = df[df['사용 여부'] == 1]
    df_sample = used_dk.loc[:, ['종목코드', '종목명', '종목 뉴스 주소']]
    category_ids = []
    category_news = []
    category_names = []

    for s in range(len(df_sample)):
        stock_news = df_sample['종목 뉴스 주소'].iloc[s].split('/')
        stock_news = stock_news[-1]
        stock_ids = df_sample['종목코드'].iloc[s]
        stock_name = df_sample['종목명'].iloc[s]
        category_ids.append(stock_ids)
        category_news.append(stock_news)
        category_names.append(stock_name)

    return category_ids, category_news, category_names


## 아마존 DB 티커 불러올때, 핀비즈에서 검색 안되는 리스트
def notfind_symbol_load():
    unfind_df = pd.read_excel('./data/notfind_symbol.xlsx')
    unfind_df_list = unfind_df.values.tolist()
    un_symbol_list = []

    for u in range(len(unfind_df_list)):
        un_symbol = unfind_df_list[u][0]
        un_symbol_list.append(un_symbol)
    return un_symbol_list


##### DB 함수들 ################################################


## DB 저장용 -> 추후 오라클 DB화
# 시황 뉴스 데이터 추가 - Question table
def market_news_insert(db, url, title, body, w_date, n_date, press, m_time):
    category = 'market_news'
    cur = db.cursor()
    sql = """insert into US_Stock_Market_News(url, title, body, w_date, n_date, press, category, market_time) values (%s, %s, %s, %s, %s, %s, %s, %s)"""
    try:
        cur.execute(sql, (url, title, body, w_date, n_date, press, category, m_time))
        db.commit()
    except pymysql.Error as msg:
        pass


# 종목 뉴스 데이터 추가 - Question table
def stock_news_insert(db, url, title, body, w_date, n_date, press, category, ticker):
    cur = db.cursor()  # ISIN
    sql = """insert into US_Stock_Market_News(url, title, body, w_date, n_date, press, category, symbol) values (%s, %s, %s, %s, %s, %s, %s, %s)"""
    try:
        cur.execute(sql, (url, title, body, w_date, n_date, press, category, ticker))
        db.commit()
    except pymysql.Error as msg:
        print(msg)
        pass
